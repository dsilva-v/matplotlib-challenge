# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# There are 249 mice taken in for lab tests
#
# Propriva is the only Drug Regimen came out to be having duplicated
#
# Capomulin comes first with least Standard error, Ceftamin being second and infubinol being third interms of having less standard deivation in it's tumor volume data
#
# There is one outlier for Infubinol.There might be one mice not responding to the tumor drug regimines, further investigation can help on finding the lacking factors
#
# The line pot for tumor volume vs time point shows how the tumor volume has come down with time indicating Capomulin seems to be working well

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_dataset = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
merged_dataset
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_count = merged_dataset["Mouse ID"].count()
print("Total mice count:",mice_count)

unique_mice_count =  merged_dataset["Mouse ID"].nunique()
print("Total unique count:",unique_mice_count)
# Out:
# Total mice count: 1893
# Total unique count: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dup_mice_ID_Time = merged_dataset[merged_dataset.duplicated()]
display(dup_mice_ID_Time[['Mouse ID','Timepoint']])
# Out:
#     Mouse ID  Timepoint
# 909     g989          0

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mice_ID_df =  merged_dataset[merged_dataset['Mouse ID']== 'g989']
dup_mice_ID_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merged_dataset[merged_dataset['Mouse ID'] != 'g989']
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_df_mice_count = clean_df['Mouse ID'].count()
#Print the number of mice in the clean DataFrame.
clean_df_mice_count
# Out:
# 1880

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

#Mean calculation
mean = merged_dataset.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()

#Median calculation
median = merged_dataset.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()

#Variance calculation
variance = merged_dataset.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()

#Standard deviation
std = merged_dataset.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()

#SEM (Standard error of the Mean)
sem = merged_dataset.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary dataframe.
summary_statistics_df = pd.DataFrame({"Mean":mean,"Median":median,"Variance":variance,"Standard Deviation":std,"SEM":sem})
summary_statistics_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
summary_statistics_data = merged_dataset.groupby('Drug Regimen').agg(
    Mean= ('Tumor Volume (mm3)', 'mean'),
    Median = ('Tumor Volume (mm3)', 'median'),
    Variance = ('Tumor Volume (mm3)', 'var'),
    StandardDeviation = ('Tumor Volume (mm3)', 'std'),
    SEM = ('Tumor Volume (mm3)', 'sem')
    )
display(summary_statistics_data)
# Out:
#                    Mean     Median   Variance  StandardDeviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764           4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177           6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684           6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577           8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479           8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083           7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070           6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704           4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562           7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355           6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

measurements_per_regimen = pd.DataFrame(merged_dataset.groupby('Drug Regimen').count()).reset_index()
measurements_per_regimen_df = measurements_per_regimen[['Drug Regimen', 'Mouse ID']]
measurements_per_regimen_df = measurements_per_regimen_df.set_index('Drug Regimen')
measurements_per_regimen_plot = measurements_per_regimen_df.plot(kind="bar", figsize=(10,5))
plt.title("Total Measurements for each drug Regimen")
measurements_per_regimen_plot.set_ylabel("Total Measures")
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
drug_regimen_list = summary_statistics_data.index.tolist()
drug_regimen_count = (merged_dataset.groupby('Drug Regimen')['Mouse ID'].count()).tolist()
plt.figure(figsize=(10, 5))
plt.title('Total Measures per Drug Regimen')
plt.ylabel('Total Measures')
plt.xlabel('Drug Regimen')
plt.bar(drug_regimen_list,drug_regimen_count, color='violet', align='center')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Showing unique value counts for male vs female mice on cleaned data frame
unique_mice_records = clean_df.drop_duplicates('Mouse ID')
display(unique_mice_records)
mice_unique_count = unique_mice_records['Sex'].value_counts()
print("Mice Count:", mice_unique_count)

mice_unique_count.plot(kind='pie',colors= ['turquoise', 'pink'], autopct = '%1.1f%%')
plt.title("Unique mice count statistics")
plt.show()
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Showing unique value counts for male vs female mice on cleaned data frame
mice_count_list= mice_unique_count.tolist()
mice_sex_categories = mice_unique_count.index.tolist()
plt.pie(mice_count_list, labels = mice_sex_categories,colors= ['turquoise', 'pink'], autopct = '%1.1f%%')
plt.title("Unique mice count statistics")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
# lambda_function = lambda drug: drug , ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
tumor_value_loc = clean_df.loc[clean_df.groupby('Mouse ID')['Timepoint'].idxmax()]
display(clean_df.groupby('Mouse ID')['Timepoint'].idxmax())
final_tumor_value_loc = tumor_value_loc.loc[(tumor_value_loc["Drug Regimen"] == "Capomulin")|
                                           (tumor_value_loc["Drug Regimen"] == "Ramicane")|
                                           (tumor_value_loc["Drug Regimen"] == "Infubinol")|
                                           (tumor_value_loc["Drug Regimen"] == "Ceftamin"), :]
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
final_tumor_value_loc
# Out:
# Mouse ID
# a203     463
# a251     473
# a262     483
# a275     493
# a366     500
#         ...
# z435    1862
# z578      84
# z581    1872
# z795    1882
# z969    1892
# Name: Timepoint, Length: 248, dtype: int64
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 463      a203    Infubinol  Female          20          23         45
# 473      a251    Infubinol  Female          21          25         45
# 493      a275     Ceftamin  Female          20          28         45
# 327      a411     Ramicane    Male           3          22         45
# 430      a444     Ramicane  Female          10          25         45
# ...       ...          ...     ...         ...         ...        ...
# 1845     y769     Ceftamin  Female           6          27         45
# 124      y793    Capomulin    Male          17          17         45
# 1855     y865     Ceftamin    Male          23          26         45
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# As this seems to be a repetive process, a for loop would help


drug_list = ['Capomulin','Infubinol','Ceftamin','Ramicane']

for drug in drug_list:
    
    drug_df = final_tumor_value_loc.loc[final_tumor_value_loc['Drug Regimen'] == drug]
    # Locate the rows which contain mice on each drug and get the tumor volumes, dataframes
    drug_tumor_values = drug_df["Tumor Volume (mm3)"]
    quartiles = drug_tumor_values.quantile([.25, .5, .75])
    lower_quartile = quartiles[.25]
    upper_quartile = quartiles[.75]
    IQR = upper_quartile - lower_quartile
    lower_bound = lower_quartile - (1.5 * IQR)
    upper_bound = upper_quartile + (1.5 * IQR)
    

    #print IQR , upper and lower bounds and drug name
    print(f'Drug Name: {drug}')
    print(f'IQR: {round(IQR,2)}')
    print(f'Lower bound:{round(lower_bound,2)}')
    print(f'Upper bound:{round(upper_bound,2)}')
    
    
    #calculate number of outliers
    number_of_outliers = drug_tumor_values.loc[(drug_df["Tumor Volume (mm3)"] >= upper_bound) | (drug_df["Tumor Volume (mm3)"] <= lower_bound)].count()
     
    #print the outliers
    print(f'Outliers for {drug}:{number_of_outliers}')
# Out:
# Drug Name: Capomulin
# IQR: 7.78
# Lower bound:20.7
# Upper bound:51.83
# Outliers for Capomulin:0
# Drug Name: Infubinol
# IQR: 11.48
# Lower bound:36.83
# Upper bound:82.74
# Outliers for Infubinol:1
# Drug Name: Ceftamin
# IQR: 15.58
# Lower bound:25.36
# Upper bound:87.67
# Outliers for Ceftamin:0
# Drug Name: Ramicane
# IQR: 9.1
# Lower bound:17.91
# Upper bound:54.31
# Outliers for Ramicane:0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
box_plot_data = [Capomulin_tumor_value, Infubinol_tumor_value, Ceftamin_tumor_value, Ramicane_tumor_value]
drug_list = ['Capomulin','Infubinol','Ceftamin','Ramicane']

#Generate a box plot
flierprops = dict(markerfacecolor='b', marker='o')
plt.boxplot(box_plot_data,labels=drug_list,flierprops=flierprops)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# using a random mouse ID with drug regimen as 'Capomulin'
Capomulin_data = clean_df.loc[clean_df['Drug Regimen'] == 'Capomulin']
Capomulin_mice_data = Capomulin_data['Mouse ID']
mouse_ID = Capomulin_mice_data.tolist()[0]
tumor_for_MouseID_list = clean_df[clean_df['Mouse ID'] == mouse_ID]['Tumor Volume (mm3)'].tolist()
timepoint_for_MouseID_list = clean_df[clean_df['Mouse ID'] == mouse_ID]['Timepoint'].tolist()
plt.plot(timepoint_for_MouseID_list,tumor_for_MouseID_list, color = 'orange')
plt.title('Time point vs Tumor volume for a capomulin treated mouse')
plt.xlabel('Time point')
plt.xticks(timepoint_for_MouseID_list)
plt.ylabel('Tumor Volume')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

df_capomulin = Capomulin_data.loc[:,['Mouse ID','Weight (g)','Tumor Volume (mm3)']]

avg_tumor_for_MouseID_df = pd.DataFrame(df_capomulin.groupby(['Mouse ID','Weight (g)'])['Tumor Volume (mm3)'].mean()).reset_index()

plt.scatter(avg_tumor_for_MouseID_df['Tumor Volume (mm3)'],avg_tumor_for_MouseID_df['Weight (g)'])
plt.xlabel('Average Tumor Volume')
plt.ylabel('Weight')
plt.title('Avg Tumor weight vs Weight')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
from scipy.stats import linregress
x_values = avg_tumor_for_MouseID_df['Weight (g)']
y_values = avg_tumor_for_MouseID_df['Tumor Volume (mm3)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
 
#Predicted values
predicted_values = x_values * slope + intercept

line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,predicted_values,"r-")
plt.title("Correlation and Regression -- Mice treated with Capomilum")
plt.xlabel("Weight in grams")
plt.ylabel("Average Tumor Volume")
plt.show()
